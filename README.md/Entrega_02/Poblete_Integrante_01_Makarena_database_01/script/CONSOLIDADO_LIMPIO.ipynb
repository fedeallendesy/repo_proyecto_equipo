# %%
import pandas as pd

df = pd.read_csv('/CONSOLIDADO_LIMPIO.csv', sep=';', encoding='latin-1')

df.head()
# Out:
#           Unnamed: 0 Frecuencia [buses/hora]      Unnamed: 2 Unnamed: 3  \
# 0                NaN                     NaN             NaN        NaN
# 1                NaN                     NaN             NaN        NaN
# 2                NaN                     NaN             NaN        NaN
# 3  Unidad de Negocio               Código TS  Código Usuario    Sentido
# 4                  9                    930c            F10c        Ida
#
#   Unnamed: 4        6            7     8     9           10  ...     30.1  \
# 0        NaN  Laboral          NaN   NaN   NaN          NaN  ...      NaN
# 1        NaN  PRENOC1          NOC  TNOC   PMA         TPMA  ...  MAÑ DOM
# 2        NaN     0:00         1:00  5:30  6:30         8:00  ...     7:30
# 3       Tipo     0:59         5:29  6:29  7:59         9:29  ...    12:59
# 4        NaN        0  0,444444444     8     8  4,666666667  ...        0
#
#       31.1     32.1      33.1         34.1   FREC_PUNTA   FREC_VALLE  \
# ...
